# %%
import numpy as np

def initialize_parameters(dim):
    w = np.zeros((dim, 1))
    b = 0
    
    return w, b

def sigmoid(z):
    s = 1 / (1 + np.exp(-z))
    
    return s

def propagate(w, b, X, Y):
    m = X.shape[1] # number of examples
    
    # Forward propagation
    A = sigmoid(np.dot(w.T, X) + b) # compute activation
    cost = -1 / m * np.sum(Y * np.log(A) + (1 - Y) * np.log(1 - A)) # compute cost
    
    # Backward propagation
    dw = 1 / m * np.dot(X, (A - Y).T)
    db = 1 / m * np.sum(A - Y)
    
    cost = np.squeeze(cost)
    
    grads = {"dw": dw,
             "db": db}
    
    return grads, cost

def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost=True):
    costs = []
    
    for i in range(num_iterations):
        
        # Cost and gradient calculation
        grads, cost = propagate(w, b, X, Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # Update rule
        w -= learning_rate * dw
        b -= learning_rate * db
        
        # Record the costs
        if i % 100 == 0:
            costs.append(cost)
        
        # Print the cost every 100 training iterations
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs
def model(X_train, Y_train, X_test, Y_test, num_iterations=2000, learning_rate=0.5, print_cost=False):
    # Initialize parameters
    w, b = initialize_parameters(X_train.shape[0])

    # Gradient descent
    parameters, _, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    
    # Retrieve parameters w and b from dictionary "parameters"
    w, b = parameters["w"], parameters["b"]
    return {"costs": costs,
            "w": w, 
            "b": b,
            "learning_rate": learning_rate,
            "num_iterations": num_iterations}

# %%
# Generate synthetic data
np.random.seed(0)
X_train = np.random.randn(20, 1000)  # 20 features, 1000 examples
Y_train = np.random.randint(2, size=(1, 1000))  # Binary labels (0 or 1), 1000 examples
X_test = np.random.randn(20, 200)  # 20 features, 200 examples
Y_test = np.random.randint(2, size=(1, 200))  # Binary labels (0 or 1), 200 examples

# %%
# Call the model function
results = model(X_train, Y_train, X_test, Y_test, num_iterations=2000, learning_rate=0.5, print_cost=True)
# Out:
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.683124
# Cost after iteration 200: 0.683124
# Cost after iteration 300: 0.683124
# Cost after iteration 400: 0.683124
# Cost after iteration 500: 0.683124
# Cost after iteration 600: 0.683124
# Cost after iteration 700: 0.683124
# Cost after iteration 800: 0.683124
# Cost after iteration 900: 0.683124
# Cost after iteration 1000: 0.683124
# Cost after iteration 1100: 0.683124
# Cost after iteration 1200: 0.683124
# Cost after iteration 1300: 0.683124
# Cost after iteration 1400: 0.683124
# Cost after iteration 1500: 0.683124
# Cost after iteration 1600: 0.683124
# Cost after iteration 1700: 0.683124
# Cost after iteration 1800: 0.683124
# Cost after iteration 1900: 0.683124
